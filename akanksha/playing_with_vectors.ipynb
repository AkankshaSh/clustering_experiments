# %%
import numpy          as np
import pandas         as pd

import datetime
import time
import sys
import re

import smart_open
print(smart_open.__version__)

from gensim.parsing.preprocessing import remove_stopwords, split_alphanum, strip_punctuation, strip_short, strip_multiple_whitespaces, strip_non_alphanum, strip_numeric
from sklearn.feature_extraction.text import TfidfVectorizer
# Out:
# 2.0.0

# %%
#data loading
df = pd.read_csv('~/Downloads/air-qual-sample.csv')
# df = df.sample(random_state=100)
df['text'] = df['text'].fillna('').apply(str)
df.head(50)
# Out:
#             published_at platform  \
# 0   2020-05-28T17:18:57Z  twitter
# 1   2020-05-28T17:18:14Z  twitter
# 2   2020-05-28T17:17:44Z  twitter
# 3   2020-05-28T17:17:38Z  twitter
# 4   2020-05-28T17:16:48Z  twitter
# 5   2020-05-28T17:16:47Z  twitter
# 6   2020-05-28T17:16:04Z  twitter
# 7   2020-05-28T17:15:53Z  twitter
# 8   2020-05-28T17:15:27Z  twitter
# 9   2020-05-28T17:15:22Z  twitter
# 10  2020-05-28T17:14:59Z  twitter
# 11  2020-05-28T17:14:56Z  twitter
# 12  2020-05-28T17:14:36Z  twitter
# 13  2020-05-28T17:14:23Z  twitter
# 14  2020-05-28T17:14:20Z  twitter
# 15  2020-05-28T17:14:01Z  twitter
# 16  2020-05-28T17:13:54Z  twitter
# 17  2020-05-28T17:13:38Z  twitter
# 18  2020-05-28T17:13:30Z  twitter
# 19  2020-05-28T17:12:50Z  twitter
# 20  2020-05-28T17:12:47Z  twitter
# 21  2020-05-28T17:12:13Z  twitter
# 22  2020-05-28T17:12:09Z  twitter
# 23  2020-05-28T17:11:28Z  twitter
# 24  2020-05-28T17:11:27Z  twitter
# 25  2020-05-28T17:11:09Z  twitter
# 26  2020-05-28T17:10:56Z  twitter
# 27  2020-05-28T17:10:09Z  twitter
# 28  2020-05-28T17:10:07Z  twitter
# 29  2020-05-28T17:10:05Z  twitter
# 30  2020-05-28T17:09:22Z  twitter
# 31  2020-05-28T17:09:19Z  twitter
# 32  2020-05-28T17:09:02Z  twitter
# 33  2020-05-28T17:09:01Z  twitter
# 34  2020-05-28T17:08:58Z  twitter
# 35  2020-05-28T17:07:45Z  twitter
# 36  2020-05-28T17:07:22Z  twitter
# 37  2020-05-28T17:06:07Z  twitter
# 38  2020-05-28T17:05:54Z  twitter
# 39  2020-05-28T17:04:41Z  twitter
# 40  2020-05-28T17:04:30Z  twitter
# 41  2020-05-28T17:04:25Z  twitter
# 42  2020-05-28T17:04:23Z  twitter
# 43  2020-05-28T17:04:12Z  twitter
# 44  2020-05-28T17:04:05Z  twitter
# 45  2020-05-28T17:03:25Z  twitter
# 46  2020-05-28T17:03:24Z  twitter
# 47  2020-05-28T17:03:13Z  twitter
# 48  2020-05-28T17:03:13Z  twitter
# 49  2020-05-28T17:02:23Z  twitter
#
#                                                  text         username  \
# 0   RT @ToLey88 Sorry but it’s illegal to use the ...        adrien4ej
# 1   RT @ninarobertsnyc I loved what @rontkim had t...          rontkim
# 2   @maggiekb1 Look, all I want to do is start an ...        maggiekb1
# 3   RT @HenryKraemer If you’re bothered by riots a...         mateosfo
# 4   RT @Exelon This is an opportunity to rebuild N...     CarbonFreeNY
# 5   I am really having a hard time this morning wi...        maggiekb1
# 6                         @parkerpomeroy Inextricably      ialhusseini
# 7   RT @CMCarlinaRivera NY's voter registration de...    CarlinaRivera
# 8   RT @FiveThirtyEight Why is a respiratory disea...        maggiekb1
# 9   Lack of healthy food options and quality sport...           ydanis
# 10  RT @isaiah_kb mural going up at 38th & chicago...      AlleenBrown
# 11  RT @YahooFinance Highlight: “The inquiry is: d...      ialhusseini
# 12  What’s the future of office buildings in NYC? ...   KeithPowersNYC
# 13  @maggiekb1 Thank you for oppressing me! Y'all ...        maggiekb1
# 14  RT @emiliainnyc Bill by @assemblymanjoe Lentol...    JuliaCarmel__
# 15  @maggiekb1 Shout-outs to my favorite "censors"...        maggiekb1
# 16  @riskyappetite @YahooFinance Given what I am w...      ialhusseini
# 17  Republican lawmakers call for go ahead so coun...     SenatorOMara
# 18  Well I found the worst take of the morning. ht...        maggiekb1
# 19  RT @housing4allNY It’s pretty simple: if you’r...    MaketheRoadNY
# 20  RT @JamaalBowmanNY This is law enforcement. Th...   sunrisemvmtnyc
# 21  RT @wewatchwatchers I’m taking up birding. Chr...         MJ_Coren
# 22  RT @AndrewMannix This building is affordable a...         mateosfo
# 23  TODAY: 1:30pm at the @NYCCouncil Stated Meetin...   MarkTreyger718
# 24  @tanyabasu honestly, same—deleting this entire...    jessicahester
# 25  Lack of healthy food options and quality sport...           ydanis
# 26  @mateosfo definitely gonna be some novel emplo...         mateosfo
# 27  The President of the United States is directly...         mateosfo
# 28  RT @amandaripley How do you survive a disaster...          eroston
# 29  Hungry? It's #NationalHamburgerDay -- you all ...  JeffreyHayzlett
# 30  @BertoliniAnnaM Gosh — I hadn’t made that conn...   RobGMacfarlane
# 31  RT @ClimateReality The climate crisis is happe...  PatriciaFahy109
# 32  “New Yorkers, they know that the tax system is...         nynurses
# 33  RT @cjocruz "22% of people who lost their jobs...     RobinHoodNYC
# 34  RT @ReElectNydia ???? The deadline to register...    JuliaCarmel__
# 35  Another day, another food distribution! Thanks...    Salamancajr80
# 36  Our own Bus Op Regan Weal interviewed on @MSNB...      TWULocal100
# 37  ?? ATTN: UWS Grocery Store Employees Free walk...  LindaBRosenthal
# 38  RT @KumarRaoNYC “Kaepernick's protests cost hi...       AMDanQuart
# 39  @dwertime The situations clearly not identical...     PoliticoRyan
# 40  @tanyabasu brb gotta rewrite my whole proposal...    jessicahester
# 41  RT @HudPowerBroker .@andrewcuomo actually crim...      KieranLalor
# 42  RT @NYSenate The ??#NYSenate is now in session...   SenatorSerrano
# 43  RT @NYSenate The ??#NYSenate is now in session...  BrianKavanaghNY
# 44  @chrislhayes Trump wants to have the first ame...    greenhousenyt
# 45  New Trump public land rules will let Alaska hu...             Pfro
# 46                                   More pretending.        B52Malmet
# 47  Good read about what nurses still need in the ...         nynurses
# 48  RT @MontefioreNYC We are so thankful to Assemb...     Fernandez4NY
# 49  @SquigglyVolcano the only time I dare do more ...           blkahn
#
#                                                  link      published_at_day  \
# 0   http://twitter.com/adrien4ej/statuses/12660563...  2020-05-28T17:18:57Z
# 36  http://twitter.com/TWULocal100/statuses/126605...  2020-05-28T17:07:22Z
# 37  http://twitter.com/LindaBRosenthal/statuses/12...  2020-05-28T17:06:07Z
# 38  http://twitter.com/AMDanQuart/statuses/1266053...  2020-05-28T17:05:54Z
# 39  http://twitter.com/PoliticoRyan/statuses/12660...  2020-05-28T17:04:41Z
# 40  http://twitter.com/jessicahester/statuses/1266...  2020-05-28T17:04:30Z
# 41  http://twitter.com/KieranLalor/statuses/126605...  2020-05-28T17:04:25Z
# 42  http://twitter.com/SenatorSerrano/statuses/126...  2020-05-28T17:04:23Z
# 43  http://twitter.com/BrianKavanaghNY/statuses/12...  2020-05-28T17:04:12Z
# 44  http://twitter.com/greenhousenyt/statuses/1266...  2020-05-28T17:04:05Z
# 45  http://twitter.com/Pfro/statuses/1266052471073...  2020-05-28T17:03:25Z
# 46  http://twitter.com/B52Malmet/statuses/12660524...  2020-05-28T17:03:24Z
# 47  http://twitter.com/nynurses/statuses/126605241...  2020-05-28T17:03:13Z
# 48  http://twitter.com/Fernandez4NY/statuses/12660...  2020-05-28T17:03:13Z
# 49  http://twitter.com/blkahn/statuses/12660522087...  2020-05-28T17:02:23Z
#
#     published_at_time  total  replies  favorites  retweets  quotes
# 0                 NaN    NaN      NaN        NaN       NaN     NaN
# 1                 NaN    NaN      NaN        NaN       NaN     NaN
# 2                 NaN    NaN      NaN        NaN       NaN     NaN
# 3                 NaN    NaN      NaN        NaN       NaN     NaN
# 4                 NaN    NaN      NaN        NaN       NaN     NaN
# 5                 NaN    NaN      NaN        NaN       NaN     NaN
# 6                 NaN    NaN      NaN        NaN       NaN     NaN
# 7                 NaN    NaN      NaN        NaN       NaN     NaN
# 8                 NaN    NaN      NaN        NaN       NaN     NaN
# 9                 NaN    NaN      NaN        NaN       NaN     NaN
# 10                NaN    NaN      NaN        NaN       NaN     NaN
# 11                NaN    NaN      NaN        NaN       NaN     NaN
# 12                NaN    NaN      NaN        NaN       NaN     NaN
# 13                NaN    NaN      NaN        NaN       NaN     NaN
# 14                NaN    NaN      NaN        NaN       NaN     NaN
# 15                NaN    NaN      NaN        NaN       NaN     NaN
# 16                NaN    NaN      NaN        NaN       NaN     NaN
# 17                NaN    NaN      NaN        NaN       NaN     NaN
# 18                NaN    NaN      NaN        NaN       NaN     NaN
# 19                NaN    NaN      NaN        NaN       NaN     NaN
# 20                NaN    NaN      NaN        NaN       NaN     NaN
# 21                NaN    NaN      NaN        NaN       NaN     NaN
# 22                NaN    NaN      NaN        NaN       NaN     NaN
# 23                NaN    NaN      NaN        NaN       NaN     NaN
# 24                NaN    NaN      NaN        NaN       NaN     NaN
# 25                NaN    NaN      NaN        NaN       NaN     NaN
# 26                NaN    NaN      NaN        NaN       NaN     NaN
# 27                NaN    NaN      NaN        NaN       NaN     NaN
# 28                NaN    NaN      NaN        NaN       NaN     NaN
# 29                NaN    NaN      NaN        NaN       NaN     NaN
# 30                NaN    NaN      NaN        NaN       NaN     NaN
# 31                NaN    NaN      NaN        NaN       NaN     NaN
# 32                NaN    NaN      NaN        NaN       NaN     NaN
# 33                NaN    NaN      NaN        NaN       NaN     NaN
# 34                NaN    NaN      NaN        NaN       NaN     NaN
# 35                NaN    NaN      NaN        NaN       NaN     NaN
# 36                NaN    NaN      NaN        NaN       NaN     NaN
# 37                NaN    NaN      NaN        NaN       NaN     NaN
# 38                NaN    NaN      NaN        NaN       NaN     NaN
# 39                NaN    NaN      NaN        NaN       NaN     NaN
# 40                NaN    NaN      NaN        NaN       NaN     NaN
# 41                NaN    NaN      NaN        NaN       NaN     NaN
# 42                NaN    NaN      NaN        NaN       NaN     NaN
# 43                NaN    NaN      NaN        NaN       NaN     NaN
# 44                NaN    NaN      NaN        NaN       NaN     NaN
# 45                NaN    NaN      NaN        NaN       NaN     NaN
# 46                NaN    NaN      NaN        NaN       NaN     NaN
# 47                NaN    NaN      NaN        NaN       NaN     NaN
# 48                NaN    NaN      NaN        NaN       NaN     NaN
# 49                NaN    NaN      NaN        NaN       NaN     NaN

# %%
#preprocessing
def clean(text):
    text = re.sub(r'(https?:\/\/)(\s)*(www\.)?(\s)*((\w|\s)+\.)*([\w\-\s]+\/)*([\w\-]+)((\?)?[\w\s]*=\s*[\w\%&]*)*', '', text, flags=re.MULTILINE) # urls
    text = re.sub(r'[\s]{0,1}([@#][\w_-]+)', '', text, flags=re.MULTILINE) # @mentions and #hashtags
    text = text.lower() # lowercase all text to use an uncased bert model
    text = text.strip(',.-_ ')
    text = split_alphanum(text.lower())
    text = remove_stopwords(text.lower())
    text = strip_non_alphanum(text.lower())
    text = strip_short(text.lower())
    text = strip_multiple_whitespaces(text.lower())
    text = re.sub('[\d]+', '', text, flags=re.MULTILINE)
    return text

''' 
def clean(text):
    text = re.sub(r'(https?:\/\/)(\s)*(www\.)?(\s)*((\w|\s)+\.)*([\w\-\s]+\/)*([\w\-]+)((\?)?[\w\s]*=\s*[\w\%&]*)*', '', document, flags=re.MULTILINE)
    text = split_alphanum(text.lower())
    text = remove_stopwords(text.lower())
    text = strip_non_alphanum(text.lower())
    text = strip_short(text.lower())
    text = strip_multiple_whitespaces(text.lower())
    return text
'''

# Change name of text column

df['clean_text'] = df['text'].apply(clean)

# remove empty text data due to the previous cleaning step
df['clean_text'] = df['clean_text'].replace('', np.nan)
df['clean_text'] = df['clean_text'].replace('nan', np.nan)
df = df.dropna(subset=['clean_text'])
df.tail(10)
# Out:
#               published_at platform  \
# 5003  2020-05-26T17:42:56Z  twitter
# 5004  2020-05-26T17:42:55Z  twitter
# 5005  2020-05-26T17:42:39Z  twitter
# 5006  2020-05-26T17:42:35Z  twitter
# 5007  2020-05-26T17:42:11Z  twitter
# 5008  2020-05-26T17:42:07Z  twitter
# 5009  2020-05-26T17:42:02Z  twitter
# 5010  2020-05-26T17:41:58Z  twitter
# 5011  2020-05-26T17:41:50Z  twitter
# 5012  2020-05-26T17:41:22Z  twitter
#
#                                                    text       username  \
# 5003  @IamQuidpro Unbelievable! Yet it happened! #sh...          NJdoc
# 5004  RT @Energy_Vision Bob Powell, founder and CEO ...    EMPIRECLEAN
# 5005  @NYGovCuomo announced that NYS's death toll ha...  CarlinaRivera
# 5006  RT @IamQuidpro Minneapolis Police officer suff...          NJdoc
# 5007  RT @johnpavlovitz .@jack and @Twitter are fail...          NJdoc
# 5008  RT @JuddLegum He also just tweeted -- and dele...          NJdoc
# 5009  RT @davidmweissman @meghanailaB @JoeNBC @Twitt...          NJdoc
# 5010  RT @WalshFreedom Every single Republican shoul...          NJdoc
# 5011  RT @vladduthiersCBS Right on @tonydokoupil. Th...    WeatherProf
# 5012  RT @kurteichenwald Ummm...wow. @GovKemp really...          NJdoc
#
#                                                    link      published_at_day  \
# 5003  http://twitter.com/NJdoc/statuses/126533763873...  2020-05-26T17:42:56Z
# 5004  http://twitter.com/EMPIRECLEAN/statuses/126533...  2020-05-26T17:42:55Z
# 5005  http://twitter.com/CarlinaRivera/statuses/1265...  2020-05-26T17:42:39Z
# 5006  http://twitter.com/NJdoc/statuses/126533755032...  2020-05-26T17:42:35Z
# 5007  http://twitter.com/NJdoc/statuses/126533744807...  2020-05-26T17:42:11Z
# 5008  http://twitter.com/NJdoc/statuses/126533743156...  2020-05-26T17:42:07Z
# 5009  http://twitter.com/NJdoc/statuses/126533741371...  2020-05-26T17:42:02Z
# 5010  http://twitter.com/NJdoc/statuses/126533739508...  2020-05-26T17:41:58Z
# 5011  http://twitter.com/WeatherProf/statuses/126533...  2020-05-26T17:41:50Z
# 5012  http://twitter.com/NJdoc/statuses/126533724325...  2020-05-26T17:41:22Z
#
#       published_at_time  total  replies  favorites  retweets  quotes  \
# 5003                NaN    NaN      NaN        NaN       NaN     NaN
# 5004                NaN    NaN      NaN        NaN       NaN     NaN
# 5005                NaN    NaN      NaN        NaN       NaN     NaN
# 5006                NaN    NaN      NaN        NaN       NaN     NaN
# 5007                NaN    NaN      NaN        NaN       NaN     NaN
# 5008                NaN    NaN      NaN        NaN       NaN     NaN
# 5009                NaN    NaN      NaN        NaN       NaN     NaN
# 5010                NaN    NaN      NaN        NaN       NaN     NaN
# 5011                NaN    NaN      NaN        NaN       NaN     NaN
# 5012                NaN    NaN      NaN        NaN       NaN     NaN
#
#                                              clean_text
# 5003                              unbelievable happened
# 5004  bob powell founder ceo brightmark talks compan...
# 5005  announced nys death toll fallen  day row feels...
# 5006  minneapolis police officer suffocates kills ma...
# 5007  failing protect millions people enforcing comm...
# 5008  tweeted deleted disgusting conspiracy theory j...
# 5009  tweets trump person this held accountable trum...
# 5010  single republican asked agree trump mail votin...
# 5011  right that love great journalist phenomenal hu...
# 5012    ummm wow thinks win reelection pile dead bodies

# %%
text = df['clean_text']
vectorizer = TfidfVectorizer(stop_words='english')
vectors = vectorizer.fit_transform(text)
words = vectorizer.get_feature_names()
print(words)
# dense = vectors.todense()
# denselist = dense.tolist()
# dense[0:100]
# Out:
# ['aapi', 'abandoned', 'abb', 'abba', 'abc', 'abdication', 'abducted', 'abhor', 'abide', 'abilities', 'ability', 'abject', 'ablaze', 'able', 'aboard', 'abolish', 'abolition', 'aboriginal', 'abort', 'aborted', 'abortion', 'abramson', 'abrasive', 'abridging', 'abroad', 'absence', 'absent', 'absentee', 'absolute', 'absolutely', 'absolutists', 'absorb', 'absorbed', 'absorbing', 'absurd', 'abt', 'abuse', 'abused', 'abusers', 'abuses', 'abusing', 'abusive', 'academia', 'academic', 'academy', 'accdg', 'accelerate', 'accelerated', 'acceleration', 'accelerator', 'accelerators', 'accept', 'acceptable', 'acceptance', 'accepted', 'accepting', 'access', 'acc
 'amazed', 'amazing', 'amazingly', 'amazon', 'ambassador', 'ambitious', 'ambulance', 'ambulances', 'amdt', 'amend', 'amendment', 'amendments', 'america', 'american', 'americans', 'americas', 'amerikkka', 'amerjcans', 'amid', 'amidst', 'amin', 'ammann', 'amnewyork', 'amounts', 'amph ...

# %%
print(vectors)
# print().sample
# vec = pd.DataFrame(densitylist, columns=words)
# Out:
#   (0, 10750)	0.3706159586089289
#   (0, 11205)	0.2964232721009357
#   (0, 6140)	0.39595576248829784
#   (0, 11399)	0.3934045655679651
#   (0, 10899)	0.3154704767305186
#   (0, 5054)	0.47295937786925424
#   (0, 9564)	0.3741881106086855
#   (1, 6077)	0.14738161155791074
#   (1, 11146)	0.14824739643949275
#   (1, 1746)	0.14599120022931764
#   (1, 1357)	0.19164679888773659
#   (1, 10093)	0.2685418916774644
#   (1, 2233)	0.21155540486653365
#   (1, 1731)	0.2685418916774644
#   (1, 1343)	0.1724279085428929
#   (1, 6649)	0.17054412941205627
#   (1, 6096)	0.16350799856390633
#   (1, 9018)	0.6346662145996009
#   (1, 872)	0.21155540486653365
#   (1, 1344)	0.1737518004523081
#   (1, 9472)	0.3352848759972401
#   (1, 6165)	0.18319437934725782
#   (2, 4680)	0.6576865481528655
#   (2, 9722)	0.471358582725486
#   (2, 6125)	0.4358944646490775
#   :	:
#   (4979, 6238)	0.2193588011694128
#   (4979, 4179)	0.27588553728726456
#   (4979, 574)	0.4533484270237916
#   (4979, 9927)	0.29628622525360127
#   (4979, 8174)	0.2240691904621071
#   (4979, 10598)	0.1371143744266411
#   (4979, 3318)	0.2266742135118958
#   (4979, 8782)	0.3067736209277831
#   (4979, 8611)	0.2341399551862937
#   (4980, 6468)	0.45684851246790237
#   (4980, 7558)	0.45684851246790237
#   (4980, 6164)	0.2989379761486176
#   (4980, 1873)	0.36947429783450625
#   (4980, 4952)	0.29795977577505794
#   (4980, 5622)	0.36947429783450625
#   (4980, 8784)	0.24860475479451738
#   (4980, 4501)	0.2638334590625884
#   (4981, 1093)	0.4110745675238797
#   (4981, 10680)	0.4110745675238797
#   (4981, 7601)	0.3921783888058407
#   (4981, 8414)	0.36837201906548594
#   (4981, 11337)	0.3113395425237366
#   (4981, 11435)	0.3238416398261619
#   (4981, 10300)	0.3238416398261619
#   (4981, 2530)	0.25662120076856026

# %%
import hdbscan

# gamma (default=5): Ignore any clusters in the flat clustering with size less than gamma, and declare points in such clusters as noise points.
# k (default=5): Reachability distances will be computed with regard to the k nearest neighbors.

# clusterer = hdbscan.RobustSingleLinkage(cut=0.5, k=10, gamma=200)
clusterer = hdbscan.RobustSingleLinkage()

cluster_labels = clusterer.fit_predict(vectors)
hierarchy = clusterer.cluster_hierarchy_
alt_labels = hierarchy.get_clusters(0.500, 5)
hierarchy.plot()
print( _.max())
# Out:
# 7

# %%
a = np.array(clusterer.labels_)
unique, counts = np.unique(a, return_counts=True)
x = dict(zip(unique, counts))

{k: v for k, v in sorted(x.items(), key=lambda item: item[1])}
# Out:
# {7: 6, 2: 7, 6: 10, 5: 11, 4: 13, 0: 14, 1: 15, 3: 29, -1: 4877}

# %%
#  9: 417,
#  38: 525,
#  2: 1999

#     ONLY INTERESTED IN THESE LABELS

labels = np.array(clusterer.labels_)
cluster_index_1 = np.where(labels == 3)
cluster_index_2 = np.where(labels == 1)
cluster_index_3 = np.where(labels == 0)
cluster_index_4 = np.where(labels == 4)
cluster_index_5 = np.where(labels == 5)

# %%
# # print(df['text'][])
# def myfunc(a):
#   return a

# x = map(myfunc, (cluster_index_1))
# print(Array(x))
# cluster_1 = []
print(cluster_index_1)
# for x in np.nditer(cluster_index_1):
#     print(x)
#     print(df['text'][x])
#     print("\n")
    
print(df['clean_text'][2989])
#   cluster_1.append(df['text'][x]);
# print(type(np.array(cluster_index_1)))

# print()
# Out:
# (array([2742, 2746, 2755, 2821, 2824, 2829, 2834, 2836, 2849, 2852, 2924,
#        2928, 2929, 2936, 2938, 2940, 2943, 2946, 2947, 2974, 2978, 2979,
#        2984, 2986, 2989, 2991, 2995, 2997, 2999]),)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-47a9c0a50250> in <module>
#      12 #     print("\n")
#      13
# ---> 14 print(df['clean_text'][2989])
#      15 #   cluster_1.append(df['text'][x]);
#      16 # print(type(np.array(cluster_index_1)))
#
# /usr/local/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4403         k = self._convert_scalar_indexer(k, kind="getitem")
#    4404         try:
# -> 4405             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4406         except KeyError as e1:
#    4407             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 2989

# %%
hierarchy.to_numpy()

# %%
hierarchy.to_pandas()

# %%
hierarchy.get_clusters(cut_distance=0, min_cluster_size=50)

# %%
clusterer = hdbscan.HDBSCAN(min_cluster_size=10, gen_min_span_tree=True)
tree = clusterer.fit(vectors)

# %%
tree.condensed_tree_.plot()

# %%
tree.single_linkage_tree_.plot()

# %%
tree.single_linkage_tree_.get_clusters(cut_distance=1)

# %%
tree.condensed_tree_.to_networkx()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.cluster as cluster
import time

# %matplotlib inline
sns.set_context('poster')
sns.set_color_codes()
plot_kwds = {'alpha' : 0.25, 's' : 80, 'linewidths':0}

# def plot_clusters(data, algorithm, args, kwds):
#     start_time = time.time()
#     labels = algorithm(*args, **kwds).fit_predict(data)
#     end_time = time.time()
#     palette = sns.color_palette('deep', np.unique(labels).max() + 1)
#     colors = [palette[x] if x >= 0 else (0.0, 0.0, 0.0) for x in labels]
#     plt.scatter(data.reshape(data.shape[0]), data.reshape(data.shape[1]), c=colors, **plot_kwds)
#     frame = plt.gca()
#     frame.axes.get_xaxis().set_visible(False)
#     frame.axes.get_yaxis().set_visible(False)
#     plt.title('Clusters found by {}'.format(str(algorithm.__name__)), fontsize=24)
#     plt.text(-0.5, 0.7, 'Clustering took {:.2f} s'.format(end_time - start_time), fontsize=14)
    

# plot_clusters(vectors, hdbscan.HDBSCAN, (), {'min_cluster_size':15})
# input = np.array(vectors, dtype=float)

x = np.array(vectors.T[0], dtype=float)
y = np.array(vectors.T[1], dtype=float)

plt.scatter(x, y, c='b', **plot_kwds)
frame = plt.gca()
frame.axes.get_xaxis().set_visible(False)
frame.axes.get_yaxis().set_visible(False)
